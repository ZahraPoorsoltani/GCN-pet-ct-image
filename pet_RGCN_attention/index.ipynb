# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir '/content/data/'
# !mkdir '/content/data/train'
# !unzip '/content/drive/MyDrive/train_s1.zip' -d '/content/data/train'
# !unzip '/content/drive/MyDrive/train_s2.zip' -d '/content/data/train'

# %%
# !rm -r '/content/data/train/2918093/'

# %%
# !python3 '/content/drive/MyDrive/pet_RGCN/train.py'
# Out:
# 100% 17305/17305 [00:00<00:00, 1940914.29it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /content/drive/MyDrive/pet_RGCN/ConvGRU.py:24: UserWarning: nn.init.orthogonal is now deprecated in favor of nn.init.orthogonal_.
#   init.orthogonal(self.reset_gate.weight)
# /content/drive/MyDrive/pet_RGCN/ConvGRU.py:25: UserWarning: nn.init.orthogonal is now deprecated in favor of nn.init.orthogonal_.
#   init.orthogonal(self.update_gate.weight)
# ...
